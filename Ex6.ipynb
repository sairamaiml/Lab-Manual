# %%
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=10000)
x_train = pad_sequences(x_train, maxlen=200)
x_test = pad_sequences(x_test, maxlen=200)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(10000, 128),
    tf.keras.layers.LSTM(64),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

# %%
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
model.fit(x_train, y_train, epochs=3, batch_size=64)
# Out:
# Epoch 1/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 19s 46ms/step - accuracy: 0.8186 - loss: 0.3906
# Epoch 2/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 18s 46ms/step - accuracy: 0.9073 - loss: 0.2375
# Epoch 3/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 19s 48ms/step - accuracy: 0.9367 - loss: 0.1705

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print("Test Accuracy:", accuracy)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.8576 - loss: 0.3554
# Test Accuracy: 0.8576400279998779

# %%
word_index = imdb.get_word_index()

sentence = "This movie was super"

encoded = [
    word_index.get(word.lower(), 2) + 3
    for word in sentence.split()
]

encoded = pad_sequences([encoded], maxlen=200)

prediction = model.predict(encoded)[0][0]

print("\nSentence:", sentence)
print("Sentiment:", "Positive" if prediction >= 0.5 else "Negative")
print("Prediction Score:", prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
#
# Sentence: This movie was super
# Sentiment: Positive
# Prediction Score: 0.51886684
